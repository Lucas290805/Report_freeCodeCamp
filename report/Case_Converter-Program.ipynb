# %% [markdown]
# ý tưởng
#
# build bộ dịch từ pascal hoặc camel thành snake case
# pascal hoặc camel sẽ dùng in hoa kí tự đầu để đánh dấu chữ đầu nên cần thay thế và chuyển dạng
# dùng list comprehesion thay vì vòng lặp for
# cấu trúc list comprehesion nếu dùng if else như sau
# list = [<kết quả> if <điều kiện đúng> else <KẾT QUẢ của đkien sai> for i in iteration ]
# cấu trúc list comprehesion nếu dùng if như sau
# list = [ for i in iteration if <điều kiện thực hiện> ]

# %%
def convert_to_snake_case(pascal_or_camel_cased_string):
    
    # tạo list để nhận giá trị
    snake_cased_char_list = [ 
        # .isupper() sẽ trả về True và False                          
        '_' + char.lower() if char.isupper()
        else char
        for char in pascal_or_camel_cased_string
    ]

    return ''.join(snake_cased_char_list).strip('_')
def main():
    print(convert_to_snake_case('DayLaMotChuoiKiTuDai'))
main()
# Out:
# day_la_mot_chuoi_ki_tu_dai
